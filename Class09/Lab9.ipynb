# %% [markdown]
# # Lab 9
#
# ## Exercise 1:
#
# Go to this website:
#
# https://developers.google.com/maps/documentation/directions/get-api-key
#
# This is the page the explains how you can obtain an API key for the Google Directions API.
#
# Obtain an API key, and then try it out with the following origin and destination:
#
# - Origin: Melbourne Central station
# - Destination: Melbourne museum
#
# When you type these locations in the web address, you have to replace the space with a `+` sign:
#
# - Origin: `Melbourne+Central+station`
# - Destination: `Melbourne+museum`
#
# So the full API address becomes:
#
# https://maps.googleapis.com/maps/api/directions/json?origin=Melbourne+Central+station&destination=Melbourne+museum&key=AIzaSyAQHpv-mVSjytkSkf_NWSVoFBtCANpgnDA
#
# Now, request the JSON string using the python `requests` library.

# %% [markdown]
# ## Exercise 2: (Quiz)
#
# Write a python code that retrieves the JSON object from this address
#
# http://api.open-notify.org/astros
#
# and then prints out all of the values in the key-value pairs. If a value is a list, then print it out using a for loop.

# %%
import requests
site='http://api.open-notify.org/astros'
response = requests.get(site)
data = response.json()
print(data)
data["number"]
# Out:
# {'number': 3, 'message': 'success', 'people': [{'craft': 'ISS', 'name': 'Chris Cassidy'}, {'craft': 'ISS', 'name': 'Anatoly Ivanishin'}, {'craft': 'ISS', 'name': 'Ivan Vagner'}]}
# 3
