# %% [markdown]
# # Class 10: Web scraping with python
#
# ## Learning outcomes
#
# At the completion of this unit students should be able to:
# 1.   Understand how to scrape web pages using the `BeautifulSoup` library
#
# ## 10.1 Scraping the internet using the `BeautifulSoup` library
#
# Scraping a website means: visiting pages on the website and downloading a copy of those pages. Typically, the scraping algorithm will navigate the website by visiting the links on each page, and then visiting and downloading the code in the linked pages.
#
# Let's check this simple example. We are going to visit a web page that has a link.

# %%
a = "<h1 class='some class'>I need to extract this text.</h1>"

a = a.replace('<h1>','')
a = a.replace('</h1>','')
print(a)
# Out:
# <h1 class='some class'>I need to extract this text.

# %%
import requests
response = requests.get("https://www.mathpractice.xyz")
data = response.text
print(data)
# Out:
# <!DOCTYPE html><html lang="en" data-critters-container=""><head><meta name="generator" content="Scully 0.0.0">
#     <!-- Google tag (gtag.js) -->
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-LWXMJ0KBMX"></script>
#     <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'G-LWXMJ0KBMX');
#     </script>
#     <script type="application/ld+json">
#     {
#       "@context": "https://schema.org/",
#       "@type": "Quiz",
#       "typicalAgeRange": "11-12",
#       "educationalLevel": "intermediate",
#       "assesses": "Algebra",
#       "educationalAlignment": [
#         {
#           "@type": "AlignmentObject",
#           "alignmentType": "educationalSubject",
#           "targetName": "Mathematics"
#         },
#         {
#           "@type": "AlignmentObject",
#           "alignmentType": "educationalSubject",
#           "targetName": "Physics"
#         }
#       ],
#       "name": "Quiz about algebra for year 7 students",
#       "about": {
#         "@type": "",
#         "name": "simplification, variable substitutions involving numbers and indices, equations, inequalities"
#       },
#       "hasPart": [
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$x$$:
# $$4 x + 2=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{11}{4}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{1\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{1}{2}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$- \\frac{w}{2 y} + \\frac{1}{w}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 2 w$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$2 y + 2$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$5$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{- w^{2} + 2 y}{2 w y}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$l$$:
# $$3 l + 5=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{-8\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{2\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 0,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{5}{3}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$\\frac{2 x}{3} - \\frac{5 x}{4 c}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 3 c - 1$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 4 c - x$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$-9$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 1,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{8 c x - 15 x}{12 c}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$\\frac{y}{5} - \\frac{v}{5 c y} + \\frac{1}{2 c}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$5 - 5 c$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$4 c v - 3 c y$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$7 y$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{2 c y^{2} - 2 v + 5 y}{10 c y}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$\\frac{t}{4 x} - \\frac{3 u}{2} + \\frac{1}{5 u x}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$t - 2$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$1 - u$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 4 t x - 2 t$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{5 t u - 30 u^{2} x + 4}{20 u x}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$5 d q + \\frac{3}{4} + \\frac{v}{d}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 5 d q v - 3$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$1$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$3 v$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{20 d^{2} q + 3 d + 4 v}{4 d}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$w$$:
# $$4 w + 5=2 w + 2$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{19}{2}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{8\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{3}{2}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$x$$:
# $$- 5 a x + 4 a + 5 x + 2=6 a + 5$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{2 a - 15}{5 \\left(a - 1\\right)}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{2 a + 21}{5 \\left(a - 1\\right)}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{2 a + 3}{5 \\left(a - 1\\right)}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$x$$:
# $$a x - x + 3=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{21}{a - 1}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{\\frac{10}{a - 1}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{3}{a - 1}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the following inequality
# $$
# 1 - 2 c \\ge 5
# $$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# c \\leq 4
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# \\frac{1}{5} \\leq c
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# c \\leq - \\frac{8}{3}
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$
# c \\leq -2
# $$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$c$$:
# $$2 c + 4=5 - 2 c$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{9}{4}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{\\frac{3}{2}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 1,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{\\frac{1}{4}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the following inequality
# $$
# 2 n - 1 \\le 3
# $$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# 0 \\leq n
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# n \\leq \\frac{7}{3}
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$
# n \\leq -3
# $$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$
# n \\leq 2
# $$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$t$$:
# $$- 3 t - 5=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{\\frac{4}{3}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{-6\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 2,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{5}{3}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$5 + \\frac{1}{q}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$-6$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$4 d + 1$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$5 d - 2 q$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{5 q + 1}{q}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$\\frac{2}{s} - \\frac{3}{2 l}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$2 l + 4$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$l - 5 s$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$l - 5$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{4 l - 3 s}{2 l s}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$x$$:
# $$4 a x - 3 x - 2=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{- \\frac{18}{4 a - 3}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 1,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{\\frac{20}{4 a - 3}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 3,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{\\frac{2}{4 a - 3}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$- \\frac{2}{5} + \\frac{2}{d}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$3 d + 3$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$3 v + 5$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$5 v + 1$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 1,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{10 - 2 d}{5 d}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Solve the equation for $$s$$:
# $$2 s + 5=0$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{-9\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$\\left\\{\\frac{3}{2}\\right\\}$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "It has no solutions
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 1,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\left\\{- \\frac{5}{2}\\right\\}$$",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#     ,
#
#         {
#             "@type": "Question",
#             "eduQuestionType": "Multiple choice",
#             "learningResourceType": "Practice problem",
#             "name": "Year 7 algebra",
#             "text": "Simplify
# $$- \\frac{b}{v} - \\frac{v}{b} - \\frac{4}{5 b}$$
# ",
#             "comment": {
#                 "@type": "",
#                 "text": ""
#             },
#             "encodingFormat": "text/markdown",
#             "suggestedAnswer": [
#                 {
#                     "@type": "Answer",
#                     "position": 3,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 4 z - 2$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 2,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$5 z + 5$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                 }
#                 },
#                 {
#                     "@type": "Answer",
#                     "position": 0,
#                     "encodingFormat": "text/markdown",
#                     "text": "$$- 3 b z + 3$$
# ",
#                     "comment": {
#                         "@type": "",
#                         "text": ""
#                     }
#                 }
#             ],
#             "acceptedAnswer": {
#                 "@type": "Answer",
#                 "position": 1,
#                 "encodingFormat": "text/markdown",
#                 "text": "$$\\frac{- 5 b^{2} - 5 v^{2} - 4 v}{5 b v}$$
# ",
#                 "comment": {
#                 "@type": "",
#                 "text": ""
#                 }
#             }
#         }
#
#
#       ]
#     }
#     </script>
#     <meta name="description" content="Free mathematics quizzes on algebra, geometry, trigonometry, differential calculus, integral calculus, set theory, discrete mathematics, graph theory, probability and statistics.">
#
#     <meta http-equiv="cache-control" content="no-cache, must-revalidate, post-check=0, pre-check=0">
#     <meta http-equiv="cache-control" content="max-age=0">
#     <meta http-equiv="expires" content="0">
#     <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT">
#     <meta http-equiv="pragma" content="no-cache">
#
#     <meta charset="utf-8">
#     <title>mathpractice.xyz | Your best math companion | All free, no ads</title>
#     <base href="/">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="icon" type="image/x-icon" href="favicon.ico">
#     <link rel="preconnect" href="https://fonts.gstatic.com">
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500&amp;display=swap" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
#     <script src="https://code.jquery.com/jquery-3.3.1.slim.min.js" integrity="sha384-q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+8abtTE1Pi6jizo" crossorigin="anonymous"></script>
#     <script src="https://cdn.jsdelivr.net/npm/popper.js@1.14.6/dist/umd/popper.min.js" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.2.1/dist/css/bootstrap.min.css" integrity="sha384-GJzZqFGwb1QTTN6wy59ffF1BuGJpLSa9DkKMp0DgiMDm4iYMj70gZWKYbI706tWS" crossorigin="anonymous">
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@4.2.1/dist/js/bootstrap.min.js" integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous"></script>
# <style>html{--mat-ripple-color:rgba(0, 0, 0, .1)}html{--mat-option-selected-state-label-text-color:#3f51b5;--mat-option-label-text-color:rgba(0, 0, 0, .87);--mat-option-hover-state-layer-color:rgba(0, 0, 0, .04);--mat-option-focus-state-layer-color:rgba(0, 0, 0, .04);--mat-option-selected-state-layer-color:rgba(0, 0, 0, .04)}html{--mat-optgroup-label-text-color:rgba(0, 0, 0, .87)}html{--mat-full-pseudo-checkbox-selected-icon-color:#ff4081;--mat-full-pseudo-checkbox-selected-checkmark-color:#fafafa;--mat-full-pseudo-checkbox-unselected-icon-color:rgba(0, 0, 0, .54);--mat-full-pseudo-checkbox-disabled-selected-checkmark-color:#fafafa;--mat-full-pseudo-checkbox-disabled-unselected-icon-color:#b0b0b0;--mat-full-pseudo-checkbox-disabled-selected-icon-color:#b0b0b0;--mat-minimal-pseudo-checkbox-selected-checkmark-color:#ff4081;--mat-minimal-pseudo-checkbox-disabled-selected-checkmark-color:#b0b0b0}html{--mat-app-background-color:#fafafa;--mat-app-text-color:rgba(0, 0, 0, .87)}html{--mat-option-label-text-font:Roboto, sans-serif;--mat-option-label-text-line-height:24px;--mat-option-label-text-size:16px;--mat-option-label-text-tracking:.03125em;--mat-option-label-text-weight:400}html{--mat-optgroup-label-text-font:Roboto, sans-serif;--mat-optgroup-label-text-line-height:24px;--mat-optgroup-label-text-size:16px;--mat-optgroup-label-text-tracking:.03125em;--mat-optgroup-label-text-weight:400}html{--mdc-elevated-card-container-shape:4px;--mdc-outlined-card-container-shape:4px;--mdc-outlined-card-outline-width:1px}html{--mdc-elevated-card-container-color:white;--mdc-elevated-card-container-elevation:0px 2px 1px -1px rgba(0, 0, 0, .2), 0px 1px 1px 0px rgba(0, 0, 0, .14), 0px 1px 3px 0px rgba(0, 0, 0, .12);--mdc-outlined-card-container-color:white;--mdc-outlined-card-outline-color:rgba(0, 0, 0, .12);--mdc-outlined-card-container-elevation:0px 0px 0px 0px rgba(0, 0, 0, .2), 0px 0px 0px 0px rgba(0, 0, 0, .14), 0px 0px 0px 0px rgba(0, 0, 0, .12);--mat-card-subtitle-text-color:rgba(0, 0, 0, .54)}html{--mat-card-title-text-font:Roboto, sans-serif;--mat-card-title-text-line-height:32px;--mat-card-title-text-size:20px;--mat-card-title-text-tracking:.0125em;--mat-card-title-text-weight:500;--mat-card-subtitle-text-font:Roboto, sans-serif;--mat-card-subtitle-text-line-height:22px;--mat-card-subtitle-text-size:14px;--mat-card-subtitle-text-tracking:.0071428571em;--mat-card-subtitle-text-weight:500}html{--mdc-linear-progress-active-indicator-height:4px;--mdc-linear-progress-track-height:4px;--mdc-linear-progress-track-shape:0}html{--mdc-plain-tooltip-container-shape:4px;--mdc-plain-tooltip-supporting-text-line-height:16px}html{--mdc-plain-tooltip-container-color:#616161;--mdc-plain-tooltip-supporting-text-color:#fff}html{--mdc-plain-tooltip-supporting-text-font:Roboto, sans-serif;--mdc-plain-tooltip-supporting-text-size:12px;--mdc-plain-tooltip-supporting-text-weight:400;--mdc-plain-tooltip-supporting-text-tracking:.0333333333em}html{--mdc-filled-text-field-active-indicator-height:1px;--mdc-filled-text-field-focus-active-indicator-height:2px;--mdc-filled-text-field-container-shape:4px;--mdc-outlined-text-field-outline-width:1px;--mdc-outlined-text-field-focus-outline-width:2px;--mdc-outlined-text-field-container-shape:4px}html{--mdc-filled-text-field-caret-color:#3f51b5;--mdc-filled-text-field-focus-active-indicator-color:#3f51b5;--mdc-filled-text-field-focus-label-text-color:rgba(63, 81, 181, .87);--mdc-filled-text-field-container-color:whitesmoke;--mdc-filled-text-field-disabled-container-color:#fafafa;--mdc-filled-text-field-label-text-color:rgba(0, 0, 0, .6);--mdc-filled-text-field-hover-label-text-color:rgba(0, 0, 0, .6);--mdc-filled-text-field-disabled-label-text-color:rgba(0, 0, 0, .38);--mdc-filled-text-field-input-text-color:rgba(0, 0, 0, .87);--mdc-filled-text-field-disabled-input-text-color:rgba(0, 0, 0, .38);--mdc-filled-text-field-input-text-placeholder-color:rgba(0, 0, 0, .6);--mdc-filled-text-field-error-hover-label-text-color:#f44336;- ...
#
# <body class="mat-typography" scully-version="0.0.0">
#     <app-root _nghost-ng-c1034927164="" ng-version="18.2.13"><div _ngcontent-ng-c1034927164="" class="category-fluid"><div _ngcontent-ng-c1034927164="" class="row mr-0 ml-0 mt-3 mb-3"><div _ngcontent-ng-c1034927164="" class="col-2"></div><div _ngcontent-ng-c1034927164="" class="col-8"><span _ngcontent-ng-c1034927164="" id="logo" style="display: inline;"><a _ngcontent-ng-c1034927164="" routerlink="/" routerlinkactive="active" href="/" class="active"><img _ngcontent-ng-c1034927164="" align="left" src="assets/images/logo.png" width="200px"></a></span><span _ngcontent-ng-c1034927164="" class="float-right" style="display: inline;"><a _ngcontent-ng-c1034927164="" href="https://www.facebook.com/mathpractice.xyz" class="nav-link float-right"><img _ngcontent-ng-c1034927164="" src="assets/images/Facebook_Logo_Primary.png" style="width: 1em; margin-right: 0.2em; margin-left: 0.2em;"></a><a _ngcontent-ng-c1034927164="" routerlink="/ai" routerlinkactive="active" class="nav-link float-right" href="/ai">AI</a><a _ngcontent-ng-c1034927164="" routerlink="/why-us" routerlinkactive="active" class="nav-link float-right" href="/why-us">Why us?</a><a _ngcontent-ng-c1034927164="" routerlink="/about" routerlinkactive="active" class="nav-link float-right" href="/about">About</a><a _ngcontent-ng-c1034927164="" class="nav-link float-right link">Parent Sign In / Create Account</a><!----><!----><!----></span><!----></div><div _ngcontent-ng-c1034927164="" class="col-2 pr-0"></div></div><!----></div><div _ngcontent-ng-c1034927164="" class="category-fluid nav-background"><app-navigation-bar _ngcontent-ng-c1034927164="" _nghost-ng-c4078895212=""><div _ngcontent-ng-c4078895212="" class="category"><div _ngcontent-ng-c4078895212="" class="row mr-0 ml-0"><div _ngcontent-ng-c4078895212="" class="col-2"></div><div _ngcontent-ng-c4078895212="" class="col-8"><nav _ngcontent-ng-c4078895212="" class="navbar navbar-expand-lg navbar-custom"><button _ngcontent-ng-c4078895212="" type="button" data-toggle="collapse" data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler navbar-light"><span _ngcontent-ng-c4078895212="" class="navbar-toggler-icon"></span></button><div _ngcontent-ng-c4078895212="" id="navbarSupportedContent" class="collapse navbar-collapse"><ul _ngcontent-ng-c4078895212="" class="navbar-nav mr-auto"><li _ngcontent-ng-c4078895212="" class="nav-item dropdown"><a _ngcontent-ng-c4078895212="" href="#" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" class="nav-link dropdown-toggle nav-menu-text"><img _ngcontent-ng-c4078895212="" src="assets/images/topics.svg" style="width: 1em; margin-right: 0.5em; margin-top: 0;">Maths by topic </a><div _ngcontent-ng-c4078895212="" aria-labelledby="navbarDropdown" class="dropdown-menu wide-dropdown-menu"><a _ngcontent-ng-c4078895212="" routerlink="/numbers" routerlinkactive="active" class="dropdown-item" href="/numbers"><img _ngcontent-ng-c4078895212="" src="assets/images/topic-numbers.svg" style="width: 1em; margin-right: 0.5em; margin-top: 0;">Numbers</a><a _ngcontent-ng-c4078895212="" routerlink="/time-date" routerlinkactive="active" class="dropdown-item" href="/time-date"><img _ngcontent-ng-c4078895212="" src="assets/images/topic-time-date.svg" style="width: 1em; margin-right: 0.5em; margin-top: 0;">Time and date</a><a _ngcontent-ng-c4078895212="" routerlink="/algebra" routerlinkactive="active" class="dropdown-item" href="/algebra"><img _ngcontent-ng-c4078895212="" src="assets/images/topic-algebra.svg" style="width: 1em; margin-right: 0.5em; margin-top: 0;">Algebra</a><a _ngcontent-ng-c4078895212="" routerlink="/functions" routerlinkactive="active" class="dropdown-item" href="/functions"><img _ngcontent-ng-c4078895212="" src="assets/images/topic-functions.svg" style="width: 1em; margin-right: 0.5em; margin-top: 0;">Functions</a><a _ngcontent-ng-c4078895212="" routerlink="/exp-log" ...
#     <script src="https://cdn.jsdelivr.net/npm/tsparticles-confetti@2.10.1/tsparticles.confetti.bundle.min.js"></script>
#     <script>
#
#         const defaults = {
#             spread: 360,
#             ticks: 50,
#             gravity: 0,
#             decay: 0.94,
#             startVelocity: 30,
#             shapes: ["star"],
#             colors: ["FFE400", "FFBD00", "E89400", "FFCA6C", "FDFFB8"],
#         };
#         helpMessagesBigKids = ["<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/surprised.svg'>Need help?<ul><li>Feel free to ask us on Skype by clicking <a style='color:white;font-weight:bold' href='https://join.skype.com/xoFr1YvyptWW'>here</a></li><li>Or you can send an email to <a style='color:white;font-weight:bold' href='mailto:info@mathpractice.xyz'>info@mathpractice.xyz</a></li></ul></div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused.svg'>Keep trying! If you need help, feel free to ask us on Skype by clicking <a style='color:white;font-weight:bold' href='https://join.skype.com/xoFr1YvyptWW'>here</a>.</div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>Woops! Try again!</div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>Woops! Give it another go! If you need help, feel free to ask us on Skype by clicking <a style='color:white;font-weight:bold' href='https://join.skype.com/xoFr1YvyptWW'>here</a>.</div>",
#             "<div class='help-box'>Need help? Shoot us an email at <a style='color:white;font-weight:bold' href='mailto:info@mathpractice.xyz'>info@mathpractice.xyz</a></div>"]
#         helpMessagesLittleKids = [
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>Woops! Try again!</div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>Woops! Give it another go!</div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>You can make it! Try again.</div>",
#             "<div class='help-box'><img style='width:1em;margin-right: 0.5em;'' src='../../../../../assets/images/confused2.svg'>I am sure you can make it! Try again!</div>",
#
#         ]
#
#         function shoot() {
#             confetti({
#                 ...defaults,
#                 particleCount: 40,
#                 scalar: 1.2,
#                 shapes: ["star"],
#             });
#
#             confetti({
#                 ...defaults,
#                 particleCount: 10,
#                 scalar: 0.75,
#                 shapes: ["circle"],
#             });
#         }
#
#
#         function nextQuiz() {
#             location.reload();
#         }
#
#         function skipQuiz() {
#             nextQuiz();
#         }
#
#         function markEmbeddedQuiz(questionName) {
#
#             var amountCorrect = 0;
#             var radiosName = document.getElementsByName(questionName);
#
#
#             for (var j = 0; j < radiosName.length; j++) {
#                 var radiosValue = radiosName[j];
#                 if (radiosValue.type === 'number') {
#                     if (radiosValue.value.trim() === "") {
#                         radiosValue.setAttribute("class", "no-answer-textbox")
#                     } else if (Number(eval(radiosValue.value.trim())) == Number(eval(radiosValue.getAttribute('tag').trim()))) {
#                         amountCorrect++;
#                         radiosValue.setAttribute("class", "correct-answer")
#                     }
#                     else if (Number(eval(radiosValue.value.trim())) != Number(eval(radiosValue.getAttribute('tag').trim()))) {
#                         radiosValue.setAttribute("class", "incorrect-answer")
#                     } else {
#                         radiosValue.setAttribute("class", "no-answer")
#                     }
#                 }
#                 else if (radiosValue.type === 'text') {
#                     if (radiosValue.getAttribute('tag').startsWith('listoforderednumbers_')) {
#                         answer = radiosValue.value.replace(',', '').split()
#                         correctAnswer = radiosValue.getAttribute('tag')
#                         correctAnswer = correctAnswer.replace('listoforderednumbers_', '')
#                         correctAnswer = correctAnswer.split(',')
#                         if (JSON.stringify(answer) === JSON.stringify(correctAnswer)) {
#                             amountCorrect++;
#                             radiosValue.setAttribute("class", "correct-answer")
#                         }
#                         else {
#                             radiosValue.setAttribute("class", "incorrect-answer")
#                         }
#
#                     } else if (radiosValue.getAttribute('tag').startsWith('listofunorderednumbers_')) {
#                         answer = radiosValue.value.split(/[ ,]+/)
#                         correctAnswer = radiosValue.getAttribute('tag')
#                         correctAnswer = correctAnswer.replace('listofunorderednumbers_', '')
#                         correctAnswer = correctAnswer.split(',')
#                         console.log(correctAnswer, radiosValue.value, answer)
#                         if (JSON.stringify(answer.sort()) === JSON.stringify(correctAnswer.sort())) {
#                             amountCorrect++;
#                             radiosValue.setAttribute("class", "correct-answer")
#                         }
#                         else {
#                             radiosValue.setAttribute("class", "incorrect-answer")
#                         }
#                     }
#                 }
#                 else {
#                     if (radiosValue.getAttribute('id') == "1" && radiosValue.checked) {
#                         amountCorrect++;
#                         document.getElementById(questionName + '_' + j).setAttribute("class", "correct-answer")
#                     } else if (radiosValue.getAttribute('id') != "1" && radiosValue.checked) {
#                         document.getElementById(questionName + '_' + j).setAttribute("class", "incorrect-answer")
#                     } else {
#                         document.getElementById(questionName + '_' + j).setAttribute("class", "no-answer")
#                     }
#                 }
#             }
#
#
#             current_url = window.location.pathname
#             let helpMessages = helpMessagesLittleKids
#             if (current_url.includes("year3_") || current_url.includes("year4_") || current_url.includes("year5_")) {
#                 helpMessages = helpMessagesLittleKids;
#             } else {
#                 helpMessages = helpMessagesBigKids;
#             }
#             var xmlHttp = new XMLHttpRequest();
#             xmlHttp.open("GET", 'https://z8a3h0cpe3.execute-api.ap-southeast-2.amazonaws.com?page=' + current_url + '_submitquiz_' + amountCorrect, false);
#             xmlHttp.send(null);
#
#
#             if (amountCorrect == 1) {
#                 setTimeout(shoot, 0);
#                 setTimeout(shoot, 100);
#                 setTimeout(shoot, 200);
#                 setTimeout(shoot, 300);
#                 setTimeout(shoot, 500);
#                 setTimeout(shoot, 1000);
#                 setTimeout(shoot, 1500);
#             } else {
#                 i = Math.floor(Math.random() * helpMessages.length);
#                 document.getElementById("help_box").innerHTML = helpMessages[i]
#             }
#
#         }
#
#
#     </script>
# <script src="runtime.28bac960c317dc0f.js" type="module"></script><script src="polyfills.734388801634ccd8.js" type="module"></script><script src="main.3abcdb621fd92591.js" type="module"></script>
#
# </body></html>

# %% [markdown]
# Next, we are going to get the link text so that we can visit the link. To do that, we need to use `BeautifulSoup`. Its documentation is https://www.crummy.com/software/BeautifulSoup/bs4/doc/.
#
# Let's take a look at an example.

# %%
from bs4 import BeautifulSoup

import requests
response = requests.get("https://abc.com")
data = response.text

data_bs = BeautifulSoup(data)

a = data_bs.find('a')


print("First link using find():", a)


list_of_links = data_bs.find_all('a')

print('The list of links:',list_of_links)


for l in list_of_links:
  print(l.get('href'))

print(len(list_of_links))
# Out:
# First link using find(): <a class="navigation__skipnav__button__link" href="#" id="skipnav" tabindex="0">Skip to Content</a>
# The list of links: [<a class="navigation__skipnav__button__link" href="#" id="skipnav" tabindex="0">Skip to Content</a>, <a aria-label="ABC" class="AnchorLink navButton__link dib logo tc fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="abc.com" data-track-global.authenticated_user_flag="false" data-track-global.personalization="false" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:home - full view:main_menu:abc.com" data-track-module_position_number="none" data-track-position_number="none" data-track-section_page="main_menu" href="/" tabindex="0"><div aria-hidden="true" class="navButton__icon dib logo"><img alt="ABC" class="sitelogo" src="https://assets-cdn.watchdisneyfe.com/delta/assets/abc/abc-nav.png"/></div><div aria-hidden="true" class="abc__link"><span class="navButton__text ttc tc dib">provider-logo</span></div></a>, <a aria-label="browse" class="AnchorLink navButton__link dib hide-mobile tc fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="browse" data-track-global.authenticated_user_flag="false" data-track-global.personalization="false" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:home - full view:main_menu:browse" data-track-module_position_number="none" data-track-position_number="none" data-track-section_page="main_menu" href="/browse" tabindex="0"><div aria-hidden="true" class="abc__link"><span class="navButton__text ttc tc dib">browse</span></div></a>, <a aria-label="Live TV" class="AnchorLink navButton__link dib hide-mobile tc fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="live tv" data-track-global.authenticated_user_flag="false" data-track-global.personalization="false" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:home - full view:main_menu:live tv" data-track-module_position_number="none" data-track-position_number="none" data-track-section_page="main_menu" href="/watch-live" tabindex="0"><div aria-hidden="true" class="abc__link"><span class="navButton__text ttc tc dib">Live TV</span></div></a>, <a aria-label="news" class="AnchorLink navButton__link dib hide-mobile tc fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="news" data-track-global.authenticated_user_flag="false" data-track-global.personalization="false" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:home - full view:main_menu:news" data-track-module_position_number="none" data-track-position_number="none" data-track-section_page="main_menu" href="/collection/news" tabindex="0"><div aria-hidden="true" class="abc__link"><span class="navButton__text ttc tc dib">news</span></div></a>, <a aria-label="try hulu" class="AnchorLink ext__button fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="hulu" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:homepage:main_menu:hulu" data-track-module_position_number="none" data-track-position_number="none" data-track-section_page="main_menu" href="https://www.hulu.com/welcome?cmp=17728&amp;utm_campaign=OO_ABC_NavButton_OnChannel_Hulu&amp;utm_medium=Display&amp;utm_source=OO_ABC" tabindex="0" target="_blank"><span aria-hidden="true" class="ext__text" tabindex="-1">try</span><img alt="" class="ext__logo" height="35" src="https://assets-cdn.watchdisneyfe.com/delta/assets/common/ENT_heroLogo_Hulu@2x.png" width="37"/></a>, <a aria-label="ABC" class="AnchorLink navButton__link dib logo tc fitt-tracker" data-track-collection_name="none" data-track-content_language="none" data-track-cta_text="abc.com" data-track-global.authenticated_user_flag="false" data-track-global.personalization="false" data-track-global.tagid="f_click01" data-track-link_name_custom="abc:home - full view:main_menu:abc.com" data-track-module_position_number="none" data-track-pos ...
# #
# /
# /browse
# /watch-live
# /collection/news
# https://www.hulu.com/welcome?cmp=17728&utm_campaign=OO_ABC_NavButton_OnChannel_Hulu&utm_medium=Display&utm_source=OO_ABC
# /
# /browse
# /watch-live
# /collection/news
# /show/ada4e644-ce0b-4590-9dac-b04ce0a446e8
# https://www.hulu.com/series/the-rookie-1138ee62-b9d9-4561-8094-3f7cda4bbd22?cmp=15111&utm_campaign=OO_ABC_HomescreenHero_OnChannel_TheRookie_0505211&utm_medium=Display&utm_source=OO_ABC
# /show/baf4f444-36a4-4340-ac11-c570f0da4977
# /movies-and-specials/90dd336a-a570-4c66-9457-8a8e1b89b374
# /show/ada4e644-ce0b-4590-9dac-b04ce0a446e8
# /show/84b1dc1c-f6f9-470f-b750-59fcfe60d9a0
# /show/b7d90f97-dbb2-4ab5-b141-f9cbeae53581
# /show/42bb0821-68c2-4543-8d0f-51ca8e7dbcf4
# /show/b052ca15-d1e1-4aa4-9568-15c87b104c02
# /show/29b9a89f-a79a-47f1-8409-2f00993a3f7e
# /show/f725135b-1988-4938-8248-813c998867ce
# /show/9bfe2f4f-41ad-4492-a6dd-0b67db180543
# /show/70207ea9-cb32-454b-a519-b40106227e32
# /show/535e2b07-18a9-4d94-9803-9ed8257b9d23
# /show/86b1d55a-b3d4-48ce-943b-d78779671fab
# /show/0b21e22d-25e3-4a05-97ba-ef51d54309fe
# /show/3d875140-de1a-43e0-99e0-836879653c00
# https://abc.com/movies-and-specials/0e02a08b-5f09-44da-bf1b-f1f7fc00d1de
# https://abc.com/news/832a8e39-3a7f-4ea0-a258-8e529b0b324a/category/1138628
# https://abc.com/news/45cc8367-a710-4b30-8f4c-06bc426d77a9/category/1138628
# /browse/abc?cid=featured_brands_abc_homepage
# /browse/freeform?cid=featured_brands_ff_homepage
# /browse/fx?cid=featured_brands_fx_homepage
# /browse/natgeo?cid=featured_brands_ng_homepage
# /browse/news?cid=featured_brands_abcnews_homepage
# https://abc.com/shows/on-hulu?cid=abc_hulu_hub_featured_brands_row
# https://disneyplus.com/?cid=DTCI-Synergy-ABC-Site-Acquisition-DisneyPlus-US-DisneyPlus-DisneyPlus-EN-BrandTile-ABC_DisneyPlus_BrandTile_Evergreen-NA
# https://bit.ly/3ahfFFy
# /
# /news
# https://disneyadsales.com/
# https://support.abc.com
# /info
# https://support.abc.com/
# https://shopabctv.com/?utm_source=abc-com&utm_medium=referral&utm_campaign=abc-navigation
# https://abcnews.go.com/
# https://www.disneyplus.com/?cid=DTCI-Synergy-ABC-Site-Acquisition-NA-US-DisneyPlus-DisneyPlus-EN-NavFooter-ABC_DisneyPlus_NavFooter_Evergreen-NA
# https://disneynow.com/
# https://www.espn.com/
# https://www.freeform.com/
# https://fxnow.fxnetworks.com/
# https://www.hulu.com/welcome?cmp=14590&utm_campaign=OO_ABC_FooterNavigation_OnChannel_Evergreen&utm_medium=Display&utm_source=OO_ABC
# https://www.nationalgeographic.com/tv/
# https://www.facebook.com/ABCNetwork/
# https://www.instagram.com/abc/
# https://www.pinterest.com/ABCTelevision
# https://www.snapchat.com/add/ABCNetwork
# https://www.tiktok.com/@abcnetwork
# https://twitter.com/ABCNetwork
# https://www.youtube.com/ABCNetwork
# https://privacy.thewaltdisneycompany.com/en/dnssmpi/
# https://privacy.thewaltdisneycompany.com/en/privacy-controls/online-tracking-and-advertising/
# /closed-captioning
# https://sites.disney.com/citizenship/
# https://disneyprivacycenter.com/kids-privacy-policy/english/
# https://privacy.thewaltdisneycompany.com/en/current-privacy-policy/your-us-state-privacy-rights/
# https://www.nielsen.com/digitalprivacy
# https://disneytermsofuse.com/
# https://disneyprivacycenter.com/
# 280

# %%
from bs4 import BeautifulSoup

import requests
response = requests.get("http://abc.com")
data = response.text
print(data)

# %% [markdown]
# Several things happened in these lines of code:
# - First of all, to use `BeautifulSoup`, we import `bs4` and create a `BeautifulSoup` object.
# - Note that the `response` object can give access to the web page content via the `text` attribute. You can also convert a JSON content into a dictionary by using the `json()` method, as we did in Class 9.
# - You can get a list of all HTML tags using the `find_all()` method in `BeautifulSoup`.
# - In each link tag, you can obtain the content of the `href` attribute using the `get()` method.
#
# ## Features of `BeautifulSoup` library
#
# You can dig into web pages using a large range of methods and properties that are provided by `BeautifulSoup`, and which we will be using in the lab:
#
# - `findChildren`: it finds children of a HTML tag
# - `find`: it finds all HTML tags with the specified name
# - `get`: gets a particular attribute value from an element object
# - `attrs`: retrieves the attributes of an element as a dictionary, and allows you to set attribute values
#
# **GOTO Lab exercises 1-3**
